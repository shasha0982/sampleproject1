# %% [markdown]
# Open image with kaggle dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os

# Set up the path to the image file
image_path = os.path.join('/kaggle/input/image-project/AC-2975-MaraIsabelFernndezNpoles.png')

# Open the image file
img = Image.open(image_path)

# Display the image
plt.imshow(img)
plt.axis('off')  # Turn off axis numbers and ticks
plt.show()

# %% [markdown]
# Machine Learning in Numpy

# %%
import numpy as np

# Define a basic perceptron for binary classification
class Perceptron:
    def __init__(self, no_of_inputs, threshold=100, learning_rate=0.01):
        self.threshold = threshold
        self.learning_rate = learning_rate
        self.weights = np.zeros(no_of_inputs + 1)
           
    def predict(self, inputs):
        summation = np.dot(inputs, self.weights[1:]) + self.weights[0]
        if summation > 0:
          activation = 1
        else:
          activation = 0            
        return activation

    def train(self, training_inputs, labels):
        for _ in range(self.threshold):
            for inputs, label in zip(training_inputs, labels):
                prediction = self.predict(inputs)
                self.weights[1:] += self.learning_rate * (label - prediction) * inputs
                self.weights[0] += self.learning_rate * (label - prediction)

# %% [markdown]
# Color Space Conversion

# %%
import cv2 

# Convert image to HSV 
img_hsv = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2HSV)

# %%
img_hsv
# Out:
# array([[[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        ...,
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
# ...

# %% [markdown]
# Skin Color Modeling

# %%
lower_skin_hsv = np.array([0, 20, 50]) 
upper_skin_hsv = np.array([20, 255, 255])

# %% [markdown]
# Skin Segmentation

# %%
skin_mask = cv2.inRange(img_hsv, lower_skin_hsv, upper_skin_hsv)

# %% [markdown]
# Skin Region Extraction

# %%
skin_regions = cv2.bitwise_and(np.array(img), np.array(img), mask=skin_mask)

# %% [markdown]
# Skin Color Classification

# %%
# Extract skin areas
skin_regions = cv2.bitwise_and(np.array(img), np.array(img), mask=skin_mask)

# Display skin regions
plt.imshow(cv2.cvtColor(skin_regions, cv2.COLOR_RGB2BGR))  # Convert to RGB for display
plt.axis('off')
plt.show()
